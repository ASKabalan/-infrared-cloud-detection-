# %% [markdown]
# ## Cloud Image Segmentation using a UNET model
# Author : *Wassim Kabalan*<br>

# %% [markdown]
# ## Imports

# %%
# @title
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

# Multiprocessing
import multiprocessing
from joblib import parallel_backend, Parallel, delayed
num_cores = multiprocessing.cpu_count()

import glob
from sklearn.model_selection import train_test_split
import os
import shutil
import random
from flax.training import orbax_utils
import orbax.checkpoint
import gc
import csv

# %%
# @title
# !pip install -q optuna
import optuna
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.2/404.2 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 10.7 MB/s eta 0:00:00

# %%
# @title
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# @title
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('../utilities')

import utilities as util
import augmentations as aug
import visualization as viz
from training_utilities import TrainingMetrics, TrainingTimer

# %% [markdown]
# # Model Creation and preprocessing

# %% [markdown]
# ### Model creation using Blocks
#
# In this code snippet, several classes representing different blocks of a U-Net architecture for semantic segmentation (named `CloudSegUNET`) are implemented using the Flax library, which is a high-performance neural network library designed for flexibility. The `jax` library is also utilized for efficient numerical computing.
#
# 1. **Importing Necessary Libraries**:
#    - Importing essential libraries and modules such as `jax`, `flax`, `optax`, and `typing`.
#
# 2. **Double Convolution Block (`DoubleConvBlock`)**:
#    - A block containing two sequential convolution layers followed by ReLU activations.
#    - The convolution operations have a kernel size of 3x3 and use 'SAME' padding.
#
# 3. **Downsampling Block (`DownBlock`)**:
#    - A block that applies a double convolution block and then performs max pooling with a window shape of 2x2 and a stride of 2 to downsample the feature map.
#
# 4. **Expansive Block (`ExpansiveBlock`)**:
#    - A block that first upsamples the input feature map to match the dimensions of the skip connection using nearest neighbor interpolation.
#    - It then concatenates the upsampled feature map with the skip connection feature map along the feature dimension.
#    - Finally, it applies a double convolution block to the concatenated feature map.
#
# 5. **U-Net Architecture (`CloudSegUNET`)**:
#    - The U-Net architecture starts with a series of downsampling blocks, each reducing the spatial dimensions of the input feature map while increasing the number of feature channels.
#    - Skip connections from each downsampling block are saved for later use in the expansive blocks.
#    - The architecture then transitions to a series of expansive blocks, each increasing the spatial dimensions of the feature map while decreasing the number of feature channels.
#    - Each expansive block uses a skip connection from the corresponding downsampling block to provide high-resolution features.
#    - Finally, a convolution layer with a single output channel is applied to generate the segmentation map.

# %%
import jax
from jax import jit, vmap, pmap, grad , numpy as jnp

from flax import linen as nn
from flax.training import train_state
import optax

from typing import Any, Callable, Sequence, Tuple, Dict

class DoubleConvBlock(nn.Module):
    input_channels: int = 128
    kernel_size: Tuple[int, int] = (3 ,3)

    @nn.compact
    def __call__(self, x):
        x = nn.Conv(features=self.input_channels, kernel_size=self.kernel_size , padding='SAME')(x)
        x = nn.relu(x)
        x = nn.Conv(features=self.input_channels, kernel_size=self.kernel_size , padding='SAME')(x)
        x = nn.relu(x)
        return x

class DownBlock(nn.Module):
    input_channels: int = 128

    @nn.compact
    def __call__(self, x):
        conv = DoubleConvBlock(self.input_channels)(x)
        x = nn.max_pool(conv, window_shape=(2,2), strides=(2,2), padding='SAME')
        return x , conv

class ExpansiveBlock(nn.Module):
    input_channels: int = 128

    @nn.compact
    def __call__(self, x , skip_connection):
        x = jax.image.resize(image=x, shape=(x.shape[0] , skip_connection.shape[1] , skip_connection.shape[2] , x.shape[3] ), method="nearest")
        x = jnp.concatenate([x ,skip_connection],axis=-1)
        x = DoubleConvBlock(self.input_channels)(x)
        return x


class CloudSegUNET(nn.Module):
    input_channels: Sequence[int]
    bottle_neck_conv: int = 512
    output_channel: int=1
    @nn.compact
    def __call__(self, x):

        skip_outputs = []
        for conv_layer in self.input_channels:
            x , conv = DownBlock(conv_layer)(x)
            skip_outputs.append((conv_layer , conv))

        #x = nn.Conv(self.bottle_neck_conv, kernel_size=(3, 3))(x)
        #x = nn.relu(x)
        #x = jax.image.resize(x, (x.shape[0] * 2, x.shape[1] * 2, x.shape[2]) , method="nearest")

        for i , (unconv_layer , skip_output)  in enumerate(reversed(skip_outputs)):
            x = ExpansiveBlock(unconv_layer)(x,skip_output)

        x = nn.Conv(self.output_channel, kernel_size=(3, 3), padding='SAME')(x)
        return x

# %% [markdown]
# ### Training functions
#
# 1. **Training State Class (`TrainState`)**:
#    - A class inheriting from `train_state.TrainState` to represent the training state which includes a model configuration dictionary containing model parameters.
#
# 2. **Creating Training State (`create_train_state`)**:
#    - Initializes the `CloudSegUNET` model with specified input channels and bottleneck convolution channels.
#    - Initializes model parameters using a random number generator (`rng`) and an input shape.
#    - Constructs an Adam optimizer with a cosine decay learning rate schedule.
#    - Returns a `TrainState` object initialized with the model, parameters, optimizer, and model configuration.
#
# 3. **Loading Training State (`load_train_state`)**:
#    - Similar to `create_train_state` but for loading a pre-existing training state from provided parameters and model configuration.
#
# 4. **Training Step (`train_step`)**:
#    - A function decorated with `@jit` for Just-In-Time compilation to speed up execution.
#    - Defines a nested `loss_fn` function to compute the loss and logits given model parameters.
#    - Utilizes `jax.value_and_grad` to obtain both the loss and gradients in a single call.
#    - Computes binary predictions, and accuracy.
#    - Applies gradient updates to the model parameters.
#    - Returns the updated training state, loss, and accuracy.
#
# 5. **Evaluation Step (`eval_step`)**:
#    - A function decorated with `@jit` for Just-In-Time compilation, used to evaluate the model on validation data.
#    - Computes the loss, binary predictions, and accuracy similar to `train_step`.
#    - Returns the loss and accuracy.
#
# 6. **Prediction (`predict`)**:
#    - A function decorated with `@jit` for Just-In-Time compilation, used to generate predictions on new data.
#    - Computes the probability of the positive class using the sigmoid function.
#    - Returns the probabilities.

# %%
class TrainState(train_state.TrainState):
    model_config: Dict  # This is the configuration or any other information about the model

def create_train_state(rng, input_shape, input_channels = [64 , 128, 256 , 512], bottle_neck_conv = 1024, learning_rate = 1e-3, total_steps = 10):
    model = CloudSegUNET(input_channels, bottle_neck_conv)
    params = model.init(rng, jnp.ones(input_shape, dtype=jnp.float32))['params']
    model_config = {"input_shape" : input_shape , "input_channels" : input_channels , "bottle_neck_conv" : bottle_neck_conv}
    # Initialize optimizer (Adam)
    cosine_decay_scheduler = optax.cosine_decay_schedule(learning_rate, decay_steps=total_steps, alpha=0.95)
    opt_adam = optax.adam(learning_rate=cosine_decay_scheduler)
    return TrainState.create(apply_fn=model.apply, params=params, tx=opt_adam,model_config=model_config)

def load_train_state(params, model_config, learning_rate = 1e-3, total_steps = 10):

    input_channels = model_config["input_shape"]
    bottle_neck_conv = model_config["bottle_neck_conv"]
    model = CloudSegUNET(input_channels,bottle_neck_conv)
    # Initialize optimizer (Adam)
    cosine_decay_scheduler = optax.cosine_decay_schedule(learning_rate, decay_steps=total_steps, alpha=0.95)
    opt_adam = optax.adam(learning_rate=cosine_decay_scheduler)
    return TrainState.create(apply_fn=model.apply, params=params, tx=opt_adam,model_config=model_config)

@jit
def train_step(state, images, labels):

    def loss_fn(params):
        logits = state.apply_fn({'params': params}, images)
        loss = jnp.mean(optax.sigmoid_binary_cross_entropy(logits=logits, labels=labels))
        return loss, logits

    grad_fn = jax.value_and_grad(loss_fn, has_aux=True)
    (loss, logits), grads = grad_fn(state.params)

    probs = jax.nn.sigmoid(logits)
    # Round to get binary predictions
    preds = jnp.round(probs)
    # Compute accuracy for binary classification
    accuracy = jnp.mean(preds == labels)
    new_state = state.apply_gradients(grads=grads)

    return new_state, loss, accuracy

@jit
def eval_step(state, images, labels):

    logits = state.apply_fn({'params': state.params}, images)
    loss = jnp.mean(optax.sigmoid_binary_cross_entropy(logits=logits, labels=labels))

    probs = jax.nn.sigmoid(logits)
    # Round to get binary predictions
    preds = jnp.round(probs)
    # Compute accuracy for binary classification
    accuracy = jnp.mean(preds == labels)

    return  loss, accuracy

@jit
def predict(state, images):
    logits = state.apply_fn({'params': state.params}, images)
    probs = jax.nn.sigmoid(logits)
    return probs

# %% [markdown]
# ### Model persistency
#
# 1. **Saving Model (`save_model`)**:
#    - Function to save the current training state of the Flax model using the orbax library.
#    - Utilizes `orbax.checkpoint.PyTreeCheckpointer` to handle the saving of the model.
#    - The `os.makedirs` function ensures the target directory exists, creating it if necessary.
#    - The `save` method of `orbax_checkpointer` is called with the `force=True` argument to allow overwriting of an existing checkpoint.
#
# 2. **Loading Model (`load_model`)**:
#    - Function to load a saved training state of the Flax model using the orbax library.
#    - Utilizes `orbax.checkpoint.PyTreeCheckpointer` to handle the restoration of the model.
#    - The `restore` method of `orbax_checkpointer` is called to load the training state from the specified model path.
#    - Extracts model parameters and configuration from the restored training state.
#    - Calls `load_train_state` with the restored parameters and configuration to recreate the training state, and returns this training state.

# %%
def save_model(state, model_path):
    """
    Save the Flax model using orbax.

    Parameters:
    - state: Flax train_state to be saved.
    - model_path: Path where the model will be saved.
    """
    orbax_checkpointer = orbax.checkpoint.PyTreeCheckpointer()
    save_args = orbax_utils.save_args_from_target({'model': state})
    target_dir = f"{model_path}/model"
    os.makedirs(target_dir, exist_ok=True)
    # The following line is new and allows overwriting of an existing checkpoint
    orbax_checkpointer.save(f"{model_path}/model", {'model': state}, save_args=save_args, force=True)

def load_model(model_path):
    """
    Load the Flax model using orbax.

    Parameters:
    - model_path: Path from where the model will be loaded.

    Returns:
    - state: Loaded Flax train_state.
    """
    orbax_checkpointer = orbax.checkpoint.PyTreeCheckpointer()
    restored_data = orbax_checkpointer.restore(model_path)
    state = restored_data['model']
    params = state['params']
    model_config = state['model_config']

    return load_train_state(params, model_config, learning_rate = 1e-3, total_steps = 10)

# %% [markdown]
# ## Data Loading and Preprocessing

# %% [markdown]
# For this image segmentation task, our data consists of FITS (Flexible Image Transport System) files.
#
# ### Opening and Preprocessing FITS files
#
# Our `open_fits_with_mask` function performs the following tasks:
#
# **File Opening:** Opens the provided `FITS` file using the `fits.open()` method.\
# **Extracting Image and Mask:** The function retrieves the actual image data (cloud) and the corresponding segmentation mask.
# Normalization: To bring the pixel values within a standard range, the cloud data is normalized using a given DR value.

# %%
DR = 2**14
def open_fits_with_mask(filename):
    image = fits.open(filename)
    cloud = image[0].data
    mask = image[1].data
    del image

    # Normalize image
    cloud  = cloud / DR
    return cloud , mask

# %% [markdown]
# ### Loading the Dataset
#
# **Retrieve File Paths:** We obtain a list of all FITS files present in our specified directory.\
# **Shuffle the List:** To ensure randomness and avoid any inherent order bias, we shuffle our list of images.\
# **Parallel Processing:** Leveraging the joblib library, we employ parallel processing to efficiently load all our FITS files using multiple cores.

# %%
images_list = glob.glob('/gdrive/MyDrive/Colab/CIRRUS/CIRRUS_DS/public_datasets/SWIMSEG/*.fits')
images_list = random.choices(images_list, k=len(images_list))

with parallel_backend('threading', n_jobs=num_cores):
    l_fits = Parallel(verbose=0)(delayed(open_fits_with_mask)(filename=r) for r in images_list)
l_fits = np.array(l_fits)

# %% [markdown]
# ### Quick Visual Inspection
#
# To verify our data loading process and get a sense of our data, we randomly select three images from our dataset.
# Display them using the util.plot_image function.

# %%
for _ in range(3):
    random_index = random.randint(0, len(l_fits) - 1)
    viz.plot_image(data=l_fits[random_index] , figsize=(6,3))

# %% [markdown]
# ### Data set gen and batching
#
# Training a neural network requires input data in batches. The custom data generator, CloudImageDataGenerator, ensures smooth data flow during training by dividing the dataset into batches and feeding it into the model. This is particularly important when the dataset is too large to fit into memory.
#
# ### Data Augmentation on the fly
#
# the data set generator is used to train on batches of images\
# Each set of batch is augmented by a parameter `aug_batch_size`
#
# ### Loading data in Jax Numpy Array
#
# The only difference between this loader and the keras loader is the fact that we add a dimension (represting the grayscale channel) for convolutions and we return directly Jax numpy arrays

# %%
class CloudImageDataGenerator(tf.keras.utils.Sequence):
    def __init__(self, x_data, y_data, batch_size=8,aug_batch_size=2, shuffle=True):
        self.x_data = x_data
        self.y_data = y_data
        self.batch_size = batch_size
        self.aug_batch_size = aug_batch_size
        self.shuffle = shuffle
        self.indices = np.arange(len(self.x_data))
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __len__(self):
        return int(np.ceil(len(self.x_data) / self.batch_size))

    def __getitem__(self, index):
        start_idx = index * self.batch_size
        end_idx = (index + 1) * self.batch_size
        batch_indices = self.indices[start_idx:end_idx]

        batch_x = self.x_data[batch_indices]
        batch_y = self.y_data[batch_indices]

        # Create a list of tuples using zip
        batch_list = list(zip(batch_x, batch_y))

        if self.aug_batch_size != 0:
            l_fits_aug = [aug.random_augment(img_mask=random.choice(batch_list)) for _ in range(self.aug_batch_size)]
            fits_images_aug = np.array(l_fits_aug)

            batch_x =  np.concatenate((batch_x, fits_images_aug[:,0]), axis=0)
            batch_y =  np.concatenate((batch_y, fits_images_aug[:,1]), axis=0)

        # Convert the TensorFlow tensors to JAX arrays
        batch_x = jnp.array(batch_x[..., np.newaxis])
        batch_y = jnp.array(batch_y[..., np.newaxis])

        return batch_x, batch_y


    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

# %% [markdown]
# Split the data set into training and validation

# %%
indices = np.arange(len(l_fits))
np.random.shuffle(indices)

# Split the indices for train and test
train_idx = indices[:int(0.8 * len(indices))]
test_idx = indices[int(0.8 * len(indices)):]

# Use the indices to split the l_fits list
all_data = l_fits
train_data = l_fits[train_idx]
test_data = l_fits[test_idx]

# Separate images and masks
X_train, y_train = train_data[:,0], train_data[:,1]
X_test, y_test = test_data[:,0], test_data[:,1]
all_train, all_val= l_fits[:,0],l_fits[:,1]

# %% [markdown]
# Load the dataset generator\
# We choose not to augment the validation set because it does not make sense

# %%
ds_train_gen = CloudImageDataGenerator(x_data=X_train,y_data=y_train,batch_size=64,aug_batch_size=16, shuffle=True)
ds_val_gen = CloudImageDataGenerator(x_data=X_test,y_data=y_test,batch_size=64,aug_batch_size=0, shuffle=True)

# %%
ds_gen = CloudImageDataGenerator(x_data=all_train,y_data=all_val,batch_size=64,aug_batch_size=0, shuffle=True)

# %% [markdown]
# # (Part 1) Training the base model

# %% [markdown]
# The following cell initializes the necessary variables and configurations for training a U-Net model. Random number generators are prepared, and the model's input shape, filter configurations, and training parameters like learning rate, number of epochs, and early stopping criteria are specified. A training state for the model is created using the `create_train_state` function. Additionally, the output path for saving the model and utility instances for tracking training metrics and time are

# %%
output_model_path = '/content/output/SWIMSEG'

# %%
# Initialize model
rng = jax.random.PRNGKey(0)
rng, init_rng = jax.random.split(rng)
input_shape = (24, 160, 128, 1)
n_batches = len(ds_train_gen)

unet_filters = [128, 64,32, 16]
bottle_neck_conv = 1024
learning_rate  = 1e-3
state = create_train_state(init_rng, input_shape,unet_filters, bottle_neck_conv,learning_rate, n_batches)
num_epochs = 50

verbose = 2
patience = 10  # Number of epochs to wait before stopping
best_val_loss = float('inf')  # Store the best validation loss
counter = 0  # Keep track of how many epochs have passed since last best validation loss

metrics = TrainingMetrics()
timer = TrainingTimer()

# %% [markdown]
# The following cell outlines the main training loop for the model, iterating through each epoch and each batch of data in the training and validation datasets. In each epoch, the training metrics are reset, and the timer is started to keep track of the training time. The model parameters are updated in each training step using the `train_step` function, and training loss and accuracy are recorded. Similarly, validation loss and accuracy are computed using the `eval_step` function. Progress and average metrics are optionally printed to the console depending on the verbosity level.
#
# If the average validation loss improves, the model checkpoint is saved, and the early stopping counter is reset. If the validation loss does not improve, the early stopping counter is incremented. If the counter reaches the specified patience, training is terminated early, and a message is printed to the console. This setup helps in both tracking the training progress and ensuring that training stops if there's no improvement, to save resources and time.

# %%
avg_train_loss = []
avg_val_loss = []
avg_train_accuracy = []
avg_val_accuracy = []

for epoch in range(num_epochs):
    metrics.reset()
    timer.start()

    for cnt, batch in enumerate(ds_train_gen):
        images, masks = batch
        state, loss, accuracy = train_step(state, images, masks)
        metrics.train_loss.append(loss)
        metrics.train_accuracy.append(accuracy)
        if verbose == 2 and cnt % ((n_batches // 10) + 1) == 0:
            avg_loss = metrics.avg_loss
            avg_accuracy = metrics.avg_accuracy
            print("\r", end="")
            print(f"Batch Number {cnt + 1}/{n_batches} - Loss: {avg_loss}, Accuracy: {avg_accuracy}", end="")

    for cnt, batch in enumerate(ds_val_gen):
        images, masks = batch
        loss, accuracy = eval_step(state, images, masks)
        metrics.test_loss.append(loss)
        metrics.test_accuracy.append(accuracy)

    epoch_time = timer.stop()
    if verbose >= 1:
        print("\r", end="")
        print(f"Epoch {epoch + 1}/{num_epochs} done - Loss: {metrics.avg_loss}, Accuracy: {metrics.avg_accuracy}, - val_Loss: {metrics.avg_val_loss}, val_Accuracy: {metrics.avg_val_acc},  Time taken: {epoch_time:.2f} seconds")
        avg_train_loss.append(metrics.avg_loss)
        avg_val_loss.append(metrics.avg_val_loss)
        avg_train_accuracy.append(metrics.avg_accuracy)
        avg_val_accuracy.append(metrics.avg_val_acc)

    if metrics.avg_val_loss < best_val_loss:
        best_val_loss = metrics.avg_val_loss
        counter = 0
        # Save the model checkpoint
        save_model(state, output_model_path)
    else:
        counter += 1
        if verbose >= 1:
            print(f"EarlyStopping counter: {counter} out of {patience}")
        if counter >= patience:
            if verbose >= 1:
                print("EarlyStopping: Stop training")
                break
# Out:
# Epoch 1/50 done - Loss: 0.6902529001235962, Accuracy: 0.48904186487197876, - val_Loss: 0.6895930767059326, val_Accuracy: 0.5034942626953125,  Time taken: 42.53 seconds
# Epoch 2/50 done - Loss: 0.6908828020095825, Accuracy: 0.4939690828323364, - val_Loss: 0.6903865933418274, val_Accuracy: 0.5034942626953125,  Time taken: 2.17 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 3/50 done - Loss: 0.6893341541290283, Accuracy: 0.5006486177444458, - val_Loss: 0.689586877822876, val_Accuracy: 0.5034942626953125,  Time taken: 2.15 seconds
# Epoch 4/50 done - Loss: 0.6892253756523132, Accuracy: 0.4970015585422516, - val_Loss: 0.6895924210548401, val_Accuracy: 0.5034942626953125,  Time taken: 2.16 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 5/50 done - Loss: 0.6888771057128906, Accuracy: 0.4985315203666687, - val_Loss: 0.6896504163742065, val_Accuracy: 0.5034942626953125,  Time taken: 2.05 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 6/50 done - Loss: 0.6889057159423828, Accuracy: 0.4987592101097107, - val_Loss: 0.6895716786384583, val_Accuracy: 0.5034942626953125,  Time taken: 2.15 seconds
# Epoch 7/50 done - Loss: 0.6888267397880554, Accuracy: 0.498239129781723, - val_Loss: 0.6896312236785889, val_Accuracy: 0.5034942626953125,  Time taken: 2.12 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 8/50 done - Loss: 0.6884990334510803, Accuracy: 0.4981723427772522, - val_Loss: 0.6895732283592224, val_Accuracy: 0.5034942626953125,  Time taken: 2.11 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 9/50 done - Loss: 0.6879363059997559, Accuracy: 0.5004326701164246, - val_Loss: 0.6897461414337158, val_Accuracy: 0.5034942626953125,  Time taken: 2.15 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 10/50 done - Loss: 0.6879991888999939, Accuracy: 0.502630889415741, - val_Loss: 0.6897382140159607, val_Accuracy: 0.5034942626953125,  Time taken: 2.09 seconds
# EarlyStopping counter: 4 out of 10
# Epoch 11/50 done - Loss: 0.6895603537559509, Accuracy: 0.4965454339981079, - val_Loss: 0.6894774436950684, val_Accuracy: 0.5034942626953125,  Time taken: 2.11 seconds
# Batch Number 11/13 - Loss: 0.6884563565254211, Accuracy: 0.4986078143119812
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-108-9c0371866f28> in <cell line: 6>()
#      10     for cnt, batch in enumerate(ds_train_gen):
#      11         images, masks = batch
# ---> 12         state, loss, accuracy = train_step(state, images, masks)
#      13         metrics.train_loss.append(loss)
#      14         metrics.train_accuracy.append(accuracy)
#
# <string> in <lambda>(_cls, count, mu, nu)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate the base model

# %%
def save_image(entry, output_prefix, counter):
    image, mask, pred = entry

    target_file = f"{output_model_path}/Results/{output_prefix}_{counter:04d}"
    viz.save_image_pred(
        cloud_image=image,
        binary_mask=mask,
        y_pred=pred,
        output_path=target_file,
        figsize=(8,4),
        predmask_cmap='jet'
    )

def evaluate_and_save_images(data_gen, state, output_prefix,evaluate=False,images_to_save=0):
    all_images = []
    all_predictions = []
    all_groundtruth = []

    # Predictions
    for batch in data_gen:
        images, masks = batch

        batch_predictions = predict(state, images)
        all_images.append(images)
        all_predictions.append(batch_predictions)
        all_groundtruth.append(masks)

    # Concatenate and squeeze
    all_images = jnp.concatenate(all_images, axis=0); x_img = all_images.squeeze(axis=-1)
    all_predictions = jnp.concatenate(all_predictions, axis=0); y_pred = all_predictions.squeeze(axis=-1)
    all_groundtruth = jnp.concatenate(all_groundtruth, axis=0); y_test = all_groundtruth.squeeze(axis=-1)

    # Evaluate
    if evaluate:
        os.makedirs(f"{output_model_path}", exist_ok=True)
        util.evaluate_model(y_test, y_pred, output_file=f"{output_model_path}/evaluation_results.md", plot_file=f"{output_model_path}/roc_plot.png")

    # Save images, predictions and ground truth
    if images_to_save != 0:
        os.makedirs(f"{output_model_path}/Results", exist_ok=True)
        entries = zip(all_images, all_groundtruth, all_predictions)
        for counter, entry in enumerate(entries, start=1):
            save_image(entry, output_prefix, counter)
            if counter >= images_to_save:
                break

        #with parallel_backend('threading', n_jobs=num_cores):
        #    Parallel(verbose=0)(delayed(save_image)(entry, output_prefix, counter) for counter, entry in enumerate(entries, start=1))

    return x_img ,y_test ,y_pred

# %%
# Evaluate the model on validation and training sets
images, masks , pred = evaluate_and_save_images(ds_gen, state, "FULL_Model_HYTA_val",True,1000)
images_t, masks_t , pred_t = evaluate_and_save_images(ds_train_gen, state, "FULL_Model_HYTA_val",False,100)

# %%
def save_metrics_to_csv(avg_train_loss, avg_val_loss, avg_train_accuracy, avg_val_accuracy, file_path='metrics.csv'):
    with open(file_path, mode='w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(['Epoch', 'Avg_Train_Loss', 'Avg_Val_Loss', 'Avg_Train_Accuracy', 'Avg_Val_Accuracy'])
        for epoch, (train_loss, val_loss, train_acc, val_acc) in enumerate(zip(avg_train_loss, avg_val_loss, avg_train_accuracy, avg_val_accuracy), start=1):
            writer.writerow([epoch, train_loss, val_loss, train_acc, val_acc])

# Call the function to save the metrics to a CSV file
save_metrics_to_csv(avg_train_loss, avg_val_loss, avg_train_accuracy, avg_val_accuracy, file_path=f'{output_model_path}/metrics.csv')

# %% [markdown]
# ## Plot some results

# %%
for _ in range(3):
    random_index = random.randint(0, len(images) - 1)
    viz.plot_image_pred(images[random_index], masks[random_index], pred[random_index], figsize=(8,4),predmask_cmap='jet')

# %% [markdown]
# # (Part 2) Hyperparameter optimizing using Optuna

# %% [markdown]
# The following cell defines an objective function for an Optuna optimization trial to find the best set of filters for a U-Net model. Here's a brief breakdown:
#
# 1. **Hyperparameter Suggestion**:
#    - Optuna's `trial.suggest_categorical` method is used to suggest a string representing a set of U-Net filters from a predefined list of options.
#
# 2. **Model Initialization**:
#    - The U-Net model is initialized with the suggested filters using the `create_train_state` function.
#
# 3. **Training Loop**:
#    - A training loop is implemented, going through a specified number of epochs, processing batches from the training data generator, and evaluating on the validation data generator.
#
# 4. **Intermediate Reporting**:
#    - The average validation loss is reported to Optuna at the end of each epoch using `trial.report`. This allows Optuna to track the progress of the trial.
#
# 5. **Pruning Check**:
#    - `trial.should_prune` is called to check if the trial should be pruned based on its performance so far. If it should be pruned, an exception is raised to stop the trial early.
#
# 6. **Early Stopping and Model Saving**:
#    - Implements an early stopping mechanism based on validation loss, and saves the model checkpoint whenever a new best validation loss is observed.

# %%
def objective(trial):
    # Suggest a set of channels

    try:
        unet_filters_str = trial.suggest_categorical(
            'unet_filters', [
                '64_128_256', '256_128_64',
                '32_64_128', '128_64_32',
                '128_256_512', '512_256_128',
                '32_64_128_256', '256_128_64_32',
                '16_32_64_128', '128_64_32_16',
                '8_16_32_64', '64_32_16_8',
                '16_32_64', '64_32_16',
                '8_16_32', '32_16_8',
                '4_8_16_32', '32_16_8_4'
            ]
        )


        print(unet_filters_str)
        # Convert the string back to a list of ints
        unet_filters = [int(x) for x in unet_filters_str.split('_')]

        # Initialize model
        rng = jax.random.PRNGKey(0)
        rng, init_rng = jax.random.split(rng)
        input_shape = (24, 160, 128, 1)
        n_batches = len(ds_train_gen)

        bottle_neck_conv = 1024
        learning_rate  = 1e-3
        state = create_train_state(init_rng, input_shape, unet_filters, bottle_neck_conv, learning_rate, n_batches)
        num_epochs = 50

        verbose = 2
        patience = 10  # Number of epochs to wait before stopping
        best_val_loss = float('inf')  # Store the best validation loss
        counter = 0  # Keep track of how many epochs have passed since last best validation loss
        output_model_path = '/output'

        metrics = TrainingMetrics()
        timer = TrainingTimer()

        for epoch in range(num_epochs):
            metrics.reset()
            timer.start()

            for cnt, batch in enumerate(ds_train_gen):
                images, masks = batch
                state, loss, accuracy = train_step(state, images, masks)
                metrics.train_loss.append(loss)
                metrics.train_accuracy.append(accuracy)
                if verbose == 2 and cnt % (n_batches // 10) == 0:
                    avg_loss = metrics.avg_loss
                    avg_accuracy = metrics.avg_accuracy
                    print("\r", end="")
                    print(f"Batch Number {cnt + 1}/{n_batches} - Loss: {avg_loss}, Accuracy: {avg_accuracy}", end="")

            for cnt, batch in enumerate(ds_val_gen):
                images, masks = batch
                loss, accuracy = eval_step(state, images, masks)
                metrics.test_loss.append(loss)
                metrics.test_accuracy.append(accuracy)

            epoch_time = timer.stop()
            if verbose >= 1:
                print("\r", end="")
                print(f"Epoch {epoch + 1}/{num_epochs} done - Loss: {metrics.avg_loss}, Accuracy: {metrics.avg_accuracy}, - val_Loss: {metrics.avg_val_loss}, val_Accuracy: {metrics.avg_val_acc},  Time taken: {epoch_time:.2f} seconds")

            # Report intermediate results to Optuna
            trial.report(metrics.avg_val_loss, epoch)

            # Check if the current trial should be pruned
            if trial.should_prune():
                raise optuna.TrialPruned()

            if metrics.avg_val_loss < best_val_loss:
                best_val_loss = metrics.avg_val_loss
                counter = 0
                # Save the model checkpoint
                save_model(state, f"{output_model_path}/{unet_filters_str}", epoch)
            else:
                counter += 1
                if verbose >= 1:
                    print(f"EarlyStopping counter: {counter} out of {patience}")
                if counter >= patience:
                    if verbose >= 1:
                        print("EarlyStopping: Stop training")
                    break
    finally:
        # Memory cleanup
        if state is not None:
            jax.tree_util.tree_map(lambda x: x.device_buffer.delete(), state)
            del state
            gc.collect()

    return best_val_loss

# %%
pruner = optuna.pruners.MedianPruner()
study = optuna.create_study(direction='minimize', pruner=pruner)
study.optimize(objective, n_trials=10)  # specify the number of trials

# Results
print('Number of finished trials: ', len(study.trials))
print('Best trial:')
trial = study.best_trial

print('Value: ', trial.value)
print('Params: ')
for key, value in trial.params.items():
    print(f'    {key}: {value}')
# Out:
# [I 2023-10-12 15:46:26,792] A new study created in memory with name: no-name-b201bc4e-e54e-4be6-9fef-87f8dabfb073
# 32_16_8
# Epoch 1/50 done - Loss: 0.42922598123550415, Accuracy: 0.8314401507377625, - val_Loss: 0.40806907415390015, val_Accuracy: 0.8396651148796082,  Time taken: 33.02 seconds
# Epoch 2/50 done - Loss: 0.39027148485183716, Accuracy: 0.8296650052070618, - val_Loss: 0.39265334606170654, val_Accuracy: 0.8396651148796082,  Time taken: 6.21 seconds
# Epoch 3/50 done - Loss: 0.3821139931678772, Accuracy: 0.8320467472076416, - val_Loss: 0.39820125699043274, val_Accuracy: 0.8396651148796082,  Time taken: 6.10 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 4/50 done - Loss: 0.3737192153930664, Accuracy: 0.832301676273346, - val_Loss: 0.3930724263191223, val_Accuracy: 0.8396651148796082,  Time taken: 6.19 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 5/50 done - Loss: 0.37469950318336487, Accuracy: 0.8305716514587402, - val_Loss: 0.3865019679069519, val_Accuracy: 0.8396651148796082,  Time taken: 6.33 seconds
# Epoch 6/50 done - Loss: 0.37915053963661194, Accuracy: 0.8291873931884766, - val_Loss: 0.38146141171455383, val_Accuracy: 0.8396651148796082,  Time taken: 6.20 seconds
# Epoch 7/50 done - Loss: 0.3776795268058777, Accuracy: 0.8317607045173645, - val_Loss: 0.3808058798313141, val_Accuracy: 0.8396651148796082,  Time taken: 6.20 seconds
# Epoch 8/50 done - Loss: 0.3720635175704956, Accuracy: 0.8289254903793335, - val_Loss: 0.37882575392723083, val_Accuracy: 0.8396651148796082,  Time taken: 6.26 seconds
# Epoch 9/50 done - Loss: 0.3735188841819763, Accuracy: 0.8309630751609802, - val_Loss: 0.3746371567249298, val_Accuracy: 0.8506201505661011,  Time taken: 6.12 seconds
# Epoch 10/50 done - Loss: 0.357700914144516, Accuracy: 0.8393532037734985, - val_Loss: 0.3691316843032837, val_Accuracy: 0.847806453704834,  Time taken: 6.18 seconds
# Epoch 11/50 done - Loss: 0.3568466007709503, Accuracy: 0.8378161787986755, - val_Loss: 0.36290380358695984, val_Accuracy: 0.8570581078529358,  Time taken: 6.24 seconds
# Epoch 12/50 done - Loss: 0.3509253263473511, Accuracy: 0.8445250391960144, - val_Loss: 0.3590531051158905, val_Accuracy: 0.8620545268058777,  Time taken: 6.29 seconds
# Epoch 13/50 done - Loss: 0.34020859003067017, Accuracy: 0.8456355929374695, - val_Loss: 0.348847895860672, val_Accuracy: 0.8602747917175293,  Time taken: 6.22 seconds
# Epoch 14/50 done - Loss: 0.34419214725494385, Accuracy: 0.8432429432868958, - val_Loss: 0.34185752272605896, val_Accuracy: 0.8647955656051636,  Time taken: 6.38 seconds
# Epoch 15/50 done - Loss: 0.33564522862434387, Accuracy: 0.843942403793335, - val_Loss: 0.34461939334869385, val_Accuracy: 0.8559492826461792,  Time taken: 6.27 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 16/50 done - Loss: 0.334215372800827, Accuracy: 0.8440578579902649, - val_Loss: 0.3386089503765106, val_Accuracy: 0.866186261177063,  Time taken: 6.23 seconds
# Epoch 17/50 done - Loss: 0.33946239948272705, Accuracy: 0.8431592583656311, - val_Loss: 0.3368361294269562, val_Accuracy: 0.86612468957901,  Time taken: 6.14 seconds
# Epoch 18/50 done - Loss: 0.3275411128997803, Accuracy: 0.8437774181365967, - val_Loss: 0.3289746642112732, val_Accuracy: 0.8680233359336853,  Time taken: 6.27 seconds
# Epoch 19/50 done - Loss: 0.3200385570526123, Accuracy: 0.8479272127151489, - val_Loss: 0.3394777178764343, val_Accuracy: 0.867316722869873,  Time taken: 6.22 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 20/50 done - Loss: 0.32318294048309326, Accuracy: 0.8438127636909485, - val_Loss: 0.32502755522727966, val_Accuracy: 0.8690872192382812,  Time taken: 6.32 seconds
# Epoch 21/50 done - Loss: 0.3210381865501404, Accuracy: 0.8448920249938965, - val_Loss: 0.32239407300949097, val_Accuracy: 0.8668551445007324,  Time taken: 6.34 seconds
# Epoch 22/50 done - Loss: 0.3187071979045868, Accuracy: 0.8492370247840881, - val_Loss: 0.32608819007873535, val_Accuracy: 0.8684591054916382,  Time taken: 6.18 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 23/50 done - Loss: 0.317459374666214, Accuracy: 0.8478718400001526, - val_Loss: 0.3190910518169403, val_Accuracy: 0.8692049980163574,  Time taken: 6.04 seconds
# Epoch 24/50 done - Loss: 0.31716135144233704, Accuracy: 0.8471008539199829, - val_Loss: 0.3240533769130707, val_Accuracy: 0.869121253490448,  Time taken: 6.29 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 25/50 done - Loss: 0.31807056069374084, Accuracy: 0.848321259021759, - val_Loss: 0.3170681297779083, val_Accuracy: 0.8718786835670471,  Time taken: 6.34 seconds
# Epoch 26/50 done - Loss: 0.31367775797843933, Accuracy: 0.8470649123191833, - val_Loss: 0.3181770443916321, val_Accuracy: 0.8697783946990967,  Time taken: 6.34 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 27/50 done - Loss: 0.3082831799983978, Accuracy: 0.846407949924469, - val_Loss: 0.3199680745601654, val_Accuracy: 0.8695465922355652,  Time taken: 6.31 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 28/50 done - Loss: 0.3066974878311157, Accuracy: 0.8496691584587097, - val_Loss: 0.3166133463382721, val_Accuracy: 0.8706769347190857,  Time taken: 6.37 seconds
# Epoch 29/50 done - Loss: 0.3092067241668701, Accuracy: 0.8507704138755798, - val_Loss: 0.313373327255249, val_Accuracy: 0.8716521859169006,  Time taken: 6.20 seconds
# Epoch 30/50 done - Loss: 0.30520302057266235, Accuracy: 0.8499268293380737, - val_Loss: 0.3160218596458435, val_Accuracy: 0.8721746206283569,  Time taken: 6.25 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 31/50 done - Loss: 0.30343353748321533, Accuracy: 0.8493260741233826, - val_Loss: 0.3072074055671692, val_Accuracy: 0.8740140199661255,  Time taken: 6.15 seconds
# Epoch 32/50 done - Loss: 0.30158141255378723, Accuracy: 0.8500925302505493, - val_Loss: 0.305060476064682, val_Accuracy: 0.8724451661109924,  Time taken: 6.29 seconds
# Epoch 33/50 done - Loss: 0.29898735880851746, Accuracy: 0.8492209911346436, - val_Loss: 0.3046022057533264, val_Accuracy: 0.8732229471206665,  Time taken: 6.09 seconds
# Epoch 34/50 done - Loss: 0.2996731102466583, Accuracy: 0.8517168760299683, - val_Loss: 0.30031895637512207, val_Accuracy: 0.8738551735877991,  Time taken: 6.27 seconds
# Epoch 35/50 done - Loss: 0.29769444465637207, Accuracy: 0.8492124676704407, - val_Loss: 0.3035264015197754, val_Accuracy: 0.8738088011741638,  Time taken: 6.16 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 36/50 done - Loss: 0.2952616512775421, Accuracy: 0.8521634936332703, - val_Loss: 0.2970796823501587, val_Accuracy: 0.8755265474319458,  Time taken: 6.18 seconds
# Epoch 37/50 done - Loss: 0.2972251772880554, Accuracy: 0.8515614867210388, - val_Loss: 0.30180785059928894, val_Accuracy: 0.8738647103309631,  Time taken: 6.04 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 38/50 done - Loss: 0.2953946590423584, Accuracy: 0.8507259488105774, - val_Loss: 0.29216763377189636, val_Accuracy: 0.8773105144500732,  Time taken: 6.37 seconds
# Epoch 39/50 done - Loss: 0.2885638475418091, Accuracy: 0.8525981307029724, - val_Loss: 0.29233476519584656, val_Accuracy: 0.8761910796165466,  Time taken: 6.30 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 40/50 done - Loss: 0.2863467037677765, Accuracy: 0.856413722038269, - val_Loss: 0.29072102904319763, val_Accuracy: 0.8782981038093567,  Time taken: 6.34 seconds
# Epoch 41/50 done - Loss: 0.29502958059310913, Accuracy: 0.8524460792541504, - val_Loss: 0.29614126682281494, val_Accuracy: 0.8761690258979797,  Time taken: 6.22 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 42/50 done - Loss: 0.29060378670692444, Accuracy: 0.8533344864845276, - val_Loss: 0.28885194659233093, val_Accuracy: 0.8786537051200867,  Time taken: 6.15 seconds
# Epoch 43/50 done - Loss: 0.2883366346359253, Accuracy: 0.852192759513855, - val_Loss: 0.29251205921173096, val_Accuracy: 0.876631498336792,  Time taken: 6.16 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 44/50 done - Loss: 0.2844298779964447, Accuracy: 0.8523643612861633, - val_Loss: 0.29627642035484314, val_Accuracy: 0.8753239512443542,  Time taken: 6.39 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 45/50 done - Loss: 0.2913222014904022, Accuracy: 0.8494004011154175, - val_Loss: 0.2933433949947357, val_Accuracy: 0.87619549036026,  Time taken: 6.26 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 46/50 done - Loss: 0.29100555181503296, Accuracy: 0.8527319431304932, - val_Loss: 0.29316434264183044, val_Accuracy: 0.8791900277137756,  Time taken: 6.17 seconds
# EarlyStopping counter: 4 out of 10
# Epoch 47/50 done - Loss: 0.2880517244338989, Accuracy: 0.85300612449646, - val_Loss: 0.28741371631622314, val_Accuracy: 0.8795682191848755,  Time taken: 6.27 seconds
# Epoch 48/50 done - Loss: 0.28970786929130554, Accuracy: 0.8541868925094604, - val_Loss: 0.2889110743999481, val_Accuracy: 0.8802164793014526,  Time taken: 6.10 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 49/50 done - Loss: 0.28001782298088074, Accuracy: 0.8556231260299683, - val_Loss: 0.28577110171318054, val_Accuracy: 0.8812715411186218,  Time taken: 6.16 seconds
# Epoch 50/50 done - Loss: 0.27917203307151794, Accuracy: 0.8525515198707581, - val_Loss: 0.2900213599205017, val_Accuracy: 0.8778407573699951,  Time taken: 6.20 seconds
# EarlyStopping counter: 1 out of 10
# [I 2023-10-12 15:52:20,292] Trial 0 finished with value: 0.28577110171318054 and parameters: {'unet_filters': '32_16_8'}. Best is trial 0 with value: 0.28577110171318054.
# 32_64_128
# Epoch 1/50 done - Loss: 0.4252963662147522, Accuracy: 0.8211138248443604, - val_Loss: 0.3982027769088745, val_Accuracy: 0.8396651148796082,  Time taken: 32.18 seconds
# Epoch 2/50 done - Loss: 0.38593798875808716, Accuracy: 0.8338886499404907, - val_Loss: 0.38916757702827454, val_Accuracy: 0.8396651148796082,  Time taken: 6.34 seconds
# Epoch 3/50 done - Loss: 0.3799269497394562, Accuracy: 0.8329967856407166, - val_Loss: 0.38142481446266174, val_Accuracy: 0.8396651148796082,  Time taken: 6.29 seconds
# Epoch 4/50 done - Loss: 0.38197562098503113, Accuracy: 0.8342949151992798, - val_Loss: 0.38360732793807983, val_Accuracy: 0.8396651148796082,  Time taken: 6.42 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 5/50 done - Loss: 0.3749845027923584, Accuracy: 0.8298066258430481, - val_Loss: 0.39798831939697266, val_Accuracy: 0.8396651148796082,  Time taken: 6.38 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 6/50 done - Loss: 0.3802987039089203, Accuracy: 0.8331564664840698, - val_Loss: 0.3796144723892212, val_Accuracy: 0.8396651148796082,  Time taken: 6.44 seconds
# Epoch 7/50 done - Loss: 0.372290700674057, Accuracy: 0.8322712779045105, - val_Loss: 0.38235753774642944, val_Accuracy: 0.8403216004371643,  Time taken: 6.36 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 8/50 done - Loss: 0.3652927875518799, Accuracy: 0.8412445783615112, - val_Loss: 0.3709524869918823, val_Accuracy: 0.8467664122581482,  Time taken: 6.36 seconds
# Epoch 9/50 done - Loss: 0.3687626123428345, Accuracy: 0.8380843997001648, - val_Loss: 0.37540021538734436, val_Accuracy: 0.8483744263648987,  Time taken: 6.37 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 10/50 done - Loss: 0.36780422925949097, Accuracy: 0.8376713991165161, - val_Loss: 0.4030191898345947, val_Accuracy: 0.8107497096061707,  Time taken: 6.41 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 11/50 done - Loss: 0.3684050440788269, Accuracy: 0.8376238942146301, - val_Loss: 0.35875239968299866, val_Accuracy: 0.8565680980682373,  Time taken: 6.25 seconds
# Epoch 12/50 done - Loss: 0.34943535923957825, Accuracy: 0.8432920575141907, - val_Loss: 0.3476673662662506, val_Accuracy: 0.8576833009719849,  Time taken: 6.56 seconds
# Epoch 13/50 done - Loss: 0.3501300513744354, Accuracy: 0.8428266644477844, - val_Loss: 0.3512633740901947, val_Accuracy: 0.8567887544631958,  Time taken: 6.33 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 14/50 done - Loss: 0.3507910668849945, Accuracy: 0.8412796258926392, - val_Loss: 0.3638274371623993, val_Accuracy: 0.8563370108604431,  Time taken: 6.53 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 15/50 done - Loss: 0.34423866868019104, Accuracy: 0.8426969051361084, - val_Loss: 0.33394041657447815, val_Accuracy: 0.8617966175079346,  Time taken: 6.41 seconds
# Epoch 16/50 done - Loss: 0.3364773988723755, Accuracy: 0.8465898036956787, - val_Loss: 0.3410811126232147, val_Accuracy: 0.8622004985809326,  Time taken: 6.40 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 17/50 done - Loss: 0.32469090819358826, Accuracy: 0.8454689979553223, - val_Loss: 0.3309788703918457, val_Accuracy: 0.8616734743118286,  Time taken: 6.32 seconds
# Epoch 18/50 done - Loss: 0.32263216376304626, Accuracy: 0.8478248119354248, - val_Loss: 0.32193678617477417, val_Accuracy: 0.8667008280754089,  Time taken: 6.34 seconds
# Epoch 19/50 done - Loss: 0.32104653120040894, Accuracy: 0.8494781255722046, - val_Loss: 0.3243813216686249, val_Accuracy: 0.865830659866333,  Time taken: 6.29 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 20/50 done - Loss: 0.31546974182128906, Accuracy: 0.8487708568572998, - val_Loss: 0.31987401843070984, val_Accuracy: 0.8710539937019348,  Time taken: 6.34 seconds
# Epoch 21/50 done - Loss: 0.31150683760643005, Accuracy: 0.8520016074180603, - val_Loss: 0.31664711236953735, val_Accuracy: 0.8705326914787292,  Time taken: 6.26 seconds
# Epoch 22/50 done - Loss: 0.31133151054382324, Accuracy: 0.8501158952713013, - val_Loss: 0.3132427930831909, val_Accuracy: 0.8719697594642639,  Time taken: 6.42 seconds
# Epoch 23/50 done - Loss: 0.3105282783508301, Accuracy: 0.8488490581512451, - val_Loss: 0.30273398756980896, val_Accuracy: 0.8745390176773071,  Time taken: 6.46 seconds
# Epoch 24/50 done - Loss: 0.3006146550178528, Accuracy: 0.8533042073249817, - val_Loss: 0.30236485600471497, val_Accuracy: 0.8760196566581726,  Time taken: 6.41 seconds
# Epoch 25/50 done - Loss: 0.3003443479537964, Accuracy: 0.855195164680481, - val_Loss: 0.3009568154811859, val_Accuracy: 0.8760600686073303,  Time taken: 6.28 seconds
# Epoch 26/50 done - Loss: 0.30145466327667236, Accuracy: 0.8515557646751404, - val_Loss: 0.2966395318508148, val_Accuracy: 0.8760400414466858,  Time taken: 6.55 seconds
# Epoch 27/50 done - Loss: 0.3012378215789795, Accuracy: 0.8541240692138672, - val_Loss: 0.3008052408695221, val_Accuracy: 0.8764613270759583,  Time taken: 6.42 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 28/50 done - Loss: 0.3001744747161865, Accuracy: 0.8502309918403625, - val_Loss: 0.29142144322395325, val_Accuracy: 0.8774595856666565,  Time taken: 6.49 seconds
# Epoch 29/50 done - Loss: 0.29237067699432373, Accuracy: 0.8573547005653381, - val_Loss: 0.2954103946685791, val_Accuracy: 0.8773816823959351,  Time taken: 6.28 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 30/50 done - Loss: 0.29211586713790894, Accuracy: 0.8541264533996582, - val_Loss: 0.29687514901161194, val_Accuracy: 0.8794862031936646,  Time taken: 6.52 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 31/50 done - Loss: 0.2880769968032837, Accuracy: 0.8544031977653503, - val_Loss: 0.297534316778183, val_Accuracy: 0.8721683025360107,  Time taken: 6.26 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 32/50 done - Loss: 0.2837491035461426, Accuracy: 0.8558768630027771, - val_Loss: 0.2791615128517151, val_Accuracy: 0.8841106295585632,  Time taken: 6.44 seconds
# Epoch 33/50 done - Loss: 0.2856143116950989, Accuracy: 0.8571577668190002, - val_Loss: 0.28049349784851074, val_Accuracy: 0.88360196352005,  Time taken: 6.22 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 34/50 done - Loss: 0.27812618017196655, Accuracy: 0.8591175675392151, - val_Loss: 0.27770495414733887, val_Accuracy: 0.8854609131813049,  Time taken: 6.42 seconds
# Epoch 35/50 done - Loss: 0.2795807719230652, Accuracy: 0.8576710820198059, - val_Loss: 0.2758078873157501, val_Accuracy: 0.8871570229530334,  Time taken: 6.18 seconds
# Epoch 36/50 done - Loss: 0.27610358595848083, Accuracy: 0.8605384230613708, - val_Loss: 0.2709289491176605, val_Accuracy: 0.8898518085479736,  Time taken: 6.38 seconds
# Epoch 37/50 done - Loss: 0.2744482457637787, Accuracy: 0.8575580716133118, - val_Loss: 0.2742849588394165, val_Accuracy: 0.8861618041992188,  Time taken: 6.50 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 38/50 done - Loss: 0.2754574418067932, Accuracy: 0.8565376996994019, - val_Loss: 0.27706360816955566, val_Accuracy: 0.8841602206230164,  Time taken: 6.40 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 39/50 done - Loss: 0.2771194279193878, Accuracy: 0.8596146106719971, - val_Loss: 0.2668474018573761, val_Accuracy: 0.8909010887145996,  Time taken: 6.25 seconds
# Epoch 40/50 done - Loss: 0.27047890424728394, Accuracy: 0.8602154850959778, - val_Loss: 0.2622547149658203, val_Accuracy: 0.8917511701583862,  Time taken: 6.41 seconds
# Epoch 41/50 done - Loss: 0.26060259342193604, Accuracy: 0.8609946966171265, - val_Loss: 0.257845938205719, val_Accuracy: 0.8906986117362976,  Time taken: 6.42 seconds
# Epoch 42/50 done - Loss: 0.26190704107284546, Accuracy: 0.8594862818717957, - val_Loss: 0.25760528445243835, val_Accuracy: 0.8904532194137573,  Time taken: 6.42 seconds
# Epoch 43/50 done - Loss: 0.2536490857601166, Accuracy: 0.8671017289161682, - val_Loss: 0.25635889172554016, val_Accuracy: 0.8942338228225708,  Time taken: 6.29 seconds
# Epoch 44/50 done - Loss: 0.25615039467811584, Accuracy: 0.8668376803398132, - val_Loss: 0.25906217098236084, val_Accuracy: 0.8924621939659119,  Time taken: 6.45 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 45/50 done - Loss: 0.2593383491039276, Accuracy: 0.8602486848831177, - val_Loss: 0.25677481293678284, val_Accuracy: 0.8905126452445984,  Time taken: 6.44 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 46/50 done - Loss: 0.25541043281555176, Accuracy: 0.8643271923065186, - val_Loss: 0.2595627009868622, val_Accuracy: 0.8910642266273499,  Time taken: 6.31 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 47/50 done - Loss: 0.2561017572879791, Accuracy: 0.8647910952568054, - val_Loss: 0.24884523451328278, val_Accuracy: 0.8967143893241882,  Time taken: 6.34 seconds
# Epoch 48/50 done - Loss: 0.2508476674556732, Accuracy: 0.8668745160102844, - val_Loss: 0.24731385707855225, val_Accuracy: 0.8970734477043152,  Time taken: 6.40 seconds
# Epoch 49/50 done - Loss: 0.2515372633934021, Accuracy: 0.8662952780723572, - val_Loss: 0.24112054705619812, val_Accuracy: 0.8995274901390076,  Time taken: 6.45 seconds
# Epoch 50/50 done - Loss: 0.2510867118835449, Accuracy: 0.8649962544441223, - val_Loss: 0.25964874029159546, val_Accuracy: 0.8887405395507812,  Time taken: 6.29 seconds
# EarlyStopping counter: 1 out of 10
# [I 2023-10-12 15:58:16,148] Trial 1 finished with value: 0.24112054705619812 and parameters: {'unet_filters': '32_64_128'}. Best is trial 1 with value: 0.24112054705619812.
# 128_64_32_16
# Epoch 1/50 done - Loss: 0.41280120611190796, Accuracy: 0.8216395974159241, - val_Loss: 0.3991246521472931, val_Accuracy: 0.8396651148796082,  Time taken: 70.73 seconds
# Epoch 2/50 done - Loss: 0.3837691843509674, Accuracy: 0.8319700360298157, - val_Loss: 0.39350053668022156, val_Accuracy: 0.8396651148796082,  Time taken: 6.86 seconds
# Epoch 3/50 done - Loss: 0.38068121671676636, Accuracy: 0.830376148223877, - val_Loss: 0.3911551833152771, val_Accuracy: 0.8396651148796082,  Time taken: 6.99 seconds
# Epoch 4/50 done - Loss: 0.3873223662376404, Accuracy: 0.8282198905944824, - val_Loss: 0.3920350670814514, val_Accuracy: 0.8396651148796082,  Time taken: 6.95 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 5/50 done - Loss: 0.3802749514579773, Accuracy: 0.8320041298866272, - val_Loss: 0.39210978150367737, val_Accuracy: 0.8396651148796082,  Time taken: 6.88 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 6/50 done - Loss: 0.377290278673172, Accuracy: 0.830501914024353, - val_Loss: 0.39529019594192505, val_Accuracy: 0.8396651148796082,  Time taken: 6.86 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 7/50 done - Loss: 0.3807905614376068, Accuracy: 0.8312855958938599, - val_Loss: 0.3935801088809967, val_Accuracy: 0.8396651148796082,  Time taken: 6.93 seconds
# EarlyStopping counter: 4 out of 10
# Epoch 8/50 done - Loss: 0.3729064166545868, Accuracy: 0.832406759262085, - val_Loss: 0.38183239102363586, val_Accuracy: 0.8396651148796082,  Time taken: 6.91 seconds
# Epoch 9/50 done - Loss: 0.3807658851146698, Accuracy: 0.8277007937431335, - val_Loss: 0.3922213912010193, val_Accuracy: 0.8396651148796082,  Time taken: 6.91 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 10/50 done - Loss: 0.37146487832069397, Accuracy: 0.8320130705833435, - val_Loss: 0.3725176155567169, val_Accuracy: 0.8483394980430603,  Time taken: 6.85 seconds
# Epoch 11/50 done - Loss: 0.3587783873081207, Accuracy: 0.838371217250824, - val_Loss: 0.3554058372974396, val_Accuracy: 0.8608706593513489,  Time taken: 6.89 seconds
# Epoch 12/50 done - Loss: 0.3550405204296112, Accuracy: 0.847268283367157, - val_Loss: 0.3423312306404114, val_Accuracy: 0.8670341968536377,  Time taken: 6.92 seconds
# Epoch 13/50 done - Loss: 0.32925406098365784, Accuracy: 0.8505581021308899, - val_Loss: 0.32041019201278687, val_Accuracy: 0.8772107362747192,  Time taken: 6.93 seconds
# Epoch 14/50 done - Loss: 0.3238706588745117, Accuracy: 0.852986216545105, - val_Loss: 0.31279969215393066, val_Accuracy: 0.8796272277832031,  Time taken: 6.94 seconds
# Epoch 15/50 done - Loss: 0.3091907799243927, Accuracy: 0.8512323498725891, - val_Loss: 0.2915531098842621, val_Accuracy: 0.8821768760681152,  Time taken: 7.09 seconds
# Epoch 16/50 done - Loss: 0.2915683388710022, Accuracy: 0.8546810150146484, - val_Loss: 0.2915065586566925, val_Accuracy: 0.8826819062232971,  Time taken: 7.07 seconds
# Epoch 17/50 done - Loss: 0.27594608068466187, Accuracy: 0.8583099842071533, - val_Loss: 0.2734052240848541, val_Accuracy: 0.8843891024589539,  Time taken: 6.96 seconds
# Epoch 18/50 done - Loss: 0.26591920852661133, Accuracy: 0.8604877591133118, - val_Loss: 0.26918497681617737, val_Accuracy: 0.8891322612762451,  Time taken: 7.02 seconds
# Epoch 19/50 done - Loss: 0.25775405764579773, Accuracy: 0.8624086380004883, - val_Loss: 0.25954222679138184, val_Accuracy: 0.8882163166999817,  Time taken: 7.07 seconds
# Epoch 20/50 done - Loss: 0.2623242735862732, Accuracy: 0.8610986471176147, - val_Loss: 0.2581433057785034, val_Accuracy: 0.8888524770736694,  Time taken: 6.93 seconds
# Epoch 21/50 done - Loss: 0.25071191787719727, Accuracy: 0.8641665577888489, - val_Loss: 0.2705298364162445, val_Accuracy: 0.889624834060669,  Time taken: 6.98 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 22/50 done - Loss: 0.24873071908950806, Accuracy: 0.8656138181686401, - val_Loss: 0.24175631999969482, val_Accuracy: 0.8972008228302002,  Time taken: 6.94 seconds
# Epoch 23/50 done - Loss: 0.2412683218717575, Accuracy: 0.8682263493537903, - val_Loss: 0.235605388879776, val_Accuracy: 0.8976848125457764,  Time taken: 7.00 seconds
# Epoch 24/50 done - Loss: 0.24576136469841003, Accuracy: 0.8630959391593933, - val_Loss: 0.25510790944099426, val_Accuracy: 0.8955466747283936,  Time taken: 6.91 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 25/50 done - Loss: 0.2335888147354126, Accuracy: 0.8688754439353943, - val_Loss: 0.22940799593925476, val_Accuracy: 0.9045068621635437,  Time taken: 7.00 seconds
# Epoch 26/50 done - Loss: 0.2289661318063736, Accuracy: 0.8695353269577026, - val_Loss: 0.23224708437919617, val_Accuracy: 0.9013576507568359,  Time taken: 7.14 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 27/50 done - Loss: 0.2319936752319336, Accuracy: 0.8685975074768066, - val_Loss: 0.2556336224079132, val_Accuracy: 0.8946932554244995,  Time taken: 7.01 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 28/50 done - Loss: 0.23183704912662506, Accuracy: 0.8698532581329346, - val_Loss: 0.21581168472766876, val_Accuracy: 0.9089202880859375,  Time taken: 7.05 seconds
# Epoch 29/50 done - Loss: 0.21922926604747772, Accuracy: 0.8717547655105591, - val_Loss: 0.21777527034282684, val_Accuracy: 0.9068604707717896,  Time taken: 7.16 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 30/50 done - Loss: 0.22389592230319977, Accuracy: 0.8725116848945618, - val_Loss: 0.2080068290233612, val_Accuracy: 0.9109973907470703,  Time taken: 6.96 seconds
# Epoch 31/50 done - Loss: 0.22186020016670227, Accuracy: 0.8749412298202515, - val_Loss: 0.21752969920635223, val_Accuracy: 0.9069728851318359,  Time taken: 7.00 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 32/50 done - Loss: 0.22288328409194946, Accuracy: 0.8740733861923218, - val_Loss: 0.20166584849357605, val_Accuracy: 0.9101656675338745,  Time taken: 6.96 seconds
# Epoch 33/50 done - Loss: 0.20859666168689728, Accuracy: 0.8773829936981201, - val_Loss: 0.2007894515991211, val_Accuracy: 0.9119524955749512,  Time taken: 6.90 seconds
# Epoch 34/50 done - Loss: 0.2103244513273239, Accuracy: 0.8792677521705627, - val_Loss: 0.20393973588943481, val_Accuracy: 0.9118348956108093,  Time taken: 6.86 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 35/50 done - Loss: 0.21063536405563354, Accuracy: 0.8787673711776733, - val_Loss: 0.18892164528369904, val_Accuracy: 0.9159669280052185,  Time taken: 6.93 seconds
# Epoch 36/50 done - Loss: 0.21923859417438507, Accuracy: 0.874843418598175, - val_Loss: 0.19926084578037262, val_Accuracy: 0.9148810505867004,  Time taken: 6.94 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 37/50 done - Loss: 0.21331046521663666, Accuracy: 0.8780063986778259, - val_Loss: 0.1920875608921051, val_Accuracy: 0.9162835478782654,  Time taken: 7.05 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 38/50 done - Loss: 0.20052021741867065, Accuracy: 0.8847442269325256, - val_Loss: 0.1801190972328186, val_Accuracy: 0.919685959815979,  Time taken: 6.87 seconds
# Epoch 39/50 done - Loss: 0.19881638884544373, Accuracy: 0.8817237615585327, - val_Loss: 0.19182853400707245, val_Accuracy: 0.9153982400894165,  Time taken: 6.79 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 40/50 done - Loss: 0.20591086149215698, Accuracy: 0.8785800337791443, - val_Loss: 0.18455688655376434, val_Accuracy: 0.9184921979904175,  Time taken: 6.99 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 41/50 done - Loss: 0.1994876116514206, Accuracy: 0.8813536763191223, - val_Loss: 0.18630287051200867, val_Accuracy: 0.9176672101020813,  Time taken: 6.96 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 42/50 done - Loss: 0.20977215468883514, Accuracy: 0.8797690272331238, - val_Loss: 0.1785951852798462, val_Accuracy: 0.9199278950691223,  Time taken: 6.98 seconds
# Epoch 43/50 done - Loss: 0.20228232443332672, Accuracy: 0.8794718980789185, - val_Loss: 0.18046227097511292, val_Accuracy: 0.9208438396453857,  Time taken: 6.80 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 44/50 done - Loss: 0.20109625160694122, Accuracy: 0.881256103515625, - val_Loss: 0.17628619074821472, val_Accuracy: 0.9216318726539612,  Time taken: 6.85 seconds
# Epoch 45/50 done - Loss: 0.19861048460006714, Accuracy: 0.8815516829490662, - val_Loss: 0.18026824295520782, val_Accuracy: 0.9221507906913757,  Time taken: 7.05 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 46/50 done - Loss: 0.2006576657295227, Accuracy: 0.8831023573875427, - val_Loss: 0.17263168096542358, val_Accuracy: 0.9246034026145935,  Time taken: 6.95 seconds
# Epoch 47/50 done - Loss: 0.1950538456439972, Accuracy: 0.8842779994010925, - val_Loss: 0.1723082810640335, val_Accuracy: 0.923284649848938,  Time taken: 6.89 seconds
# Epoch 48/50 done - Loss: 0.19348055124282837, Accuracy: 0.8844321966171265, - val_Loss: 0.18675731122493744, val_Accuracy: 0.9188176989555359,  Time taken: 6.83 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 49/50 done - Loss: 0.18831349909305573, Accuracy: 0.8878300786018372, - val_Loss: 0.16862954199314117, val_Accuracy: 0.9246253967285156,  Time taken: 6.84 seconds
# Epoch 50/50 done - Loss: 0.19108036160469055, Accuracy: 0.8850902318954468, - val_Loss: 0.17747052013874054, val_Accuracy: 0.9209322929382324,  Time taken: 7.00 seconds
# EarlyStopping counter: 1 out of 10
# [I 2023-10-12 16:05:26,089] Trial 2 finished with value: 0.16862954199314117 and parameters: {'unet_filters': '128_64_32_16'}. Best is trial 2 with value: 0.16862954199314117.
# 64_32_16_8
# Epoch 1/50 done - Loss: 0.41884252429008484, Accuracy: 0.8236442804336548, - val_Loss: 0.41089004278182983, val_Accuracy: 0.8396651148796082,  Time taken: 46.62 seconds
# Epoch 2/50 done - Loss: 0.3850065767765045, Accuracy: 0.8319957852363586, - val_Loss: 0.39606189727783203, val_Accuracy: 0.8396651148796082,  Time taken: 6.41 seconds
# Epoch 3/50 done - Loss: 0.38203853368759155, Accuracy: 0.830338716506958, - val_Loss: 0.38815873861312866, val_Accuracy: 0.8396651148796082,  Time taken: 6.53 seconds
# Epoch 4/50 done - Loss: 0.37919098138809204, Accuracy: 0.8305638432502747, - val_Loss: 0.39532044529914856, val_Accuracy: 0.8396651148796082,  Time taken: 6.42 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 5/50 done - Loss: 0.37785661220550537, Accuracy: 0.8301802277565002, - val_Loss: 0.3873157799243927, val_Accuracy: 0.8396651148796082,  Time taken: 6.47 seconds
# Epoch 6/50 done - Loss: 0.38169971108436584, Accuracy: 0.8281863331794739, - val_Loss: 0.3931695818901062, val_Accuracy: 0.8396651148796082,  Time taken: 6.19 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 7/50 done - Loss: 0.3733299970626831, Accuracy: 0.8325898051261902, - val_Loss: 0.38037747144699097, val_Accuracy: 0.8396651148796082,  Time taken: 6.36 seconds
# Epoch 8/50 done - Loss: 0.3712979853153229, Accuracy: 0.8320439457893372, - val_Loss: 0.3843402862548828, val_Accuracy: 0.8396651148796082,  Time taken: 6.40 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 9/50 done - Loss: 0.375724196434021, Accuracy: 0.8334243297576904, - val_Loss: 0.39042097330093384, val_Accuracy: 0.8396651148796082,  Time taken: 6.36 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 10/50 done - Loss: 0.3583625853061676, Accuracy: 0.8427145481109619, - val_Loss: 0.3586799204349518, val_Accuracy: 0.8590086102485657,  Time taken: 6.25 seconds
# Epoch 11/50 done - Loss: 0.34908920526504517, Accuracy: 0.8489974737167358, - val_Loss: 0.3529638350009918, val_Accuracy: 0.8675123453140259,  Time taken: 6.35 seconds
# Epoch 12/50 done - Loss: 0.34949377179145813, Accuracy: 0.8509546518325806, - val_Loss: 0.35878679156303406, val_Accuracy: 0.8723322153091431,  Time taken: 6.42 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 13/50 done - Loss: 0.3369283974170685, Accuracy: 0.8538072109222412, - val_Loss: 0.33755064010620117, val_Accuracy: 0.8768875598907471,  Time taken: 6.39 seconds
# Epoch 14/50 done - Loss: 0.3360876142978668, Accuracy: 0.8507099151611328, - val_Loss: 0.3305109739303589, val_Accuracy: 0.8784661889076233,  Time taken: 6.49 seconds
# Epoch 15/50 done - Loss: 0.3301185369491577, Accuracy: 0.8556798696517944, - val_Loss: 0.33073797821998596, val_Accuracy: 0.8803574442863464,  Time taken: 6.35 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 16/50 done - Loss: 0.3198568522930145, Accuracy: 0.852979838848114, - val_Loss: 0.3090873956680298, val_Accuracy: 0.8810605406761169,  Time taken: 6.33 seconds
# Epoch 17/50 done - Loss: 0.30066147446632385, Accuracy: 0.8543242812156677, - val_Loss: 0.3116031587123871, val_Accuracy: 0.880408763885498,  Time taken: 6.30 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 18/50 done - Loss: 0.2920713722705841, Accuracy: 0.8552902340888977, - val_Loss: 0.2912880480289459, val_Accuracy: 0.8818349242210388,  Time taken: 6.38 seconds
# Epoch 19/50 done - Loss: 0.28847455978393555, Accuracy: 0.8549567461013794, - val_Loss: 0.28286758065223694, val_Accuracy: 0.8804868459701538,  Time taken: 6.44 seconds
# Epoch 20/50 done - Loss: 0.27738767862319946, Accuracy: 0.8577463626861572, - val_Loss: 0.2727692127227783, val_Accuracy: 0.8842817544937134,  Time taken: 6.35 seconds
# Epoch 21/50 done - Loss: 0.2789572477340698, Accuracy: 0.8545982241630554, - val_Loss: 0.2696613669395447, val_Accuracy: 0.8868060111999512,  Time taken: 6.40 seconds
# Epoch 22/50 done - Loss: 0.26967549324035645, Accuracy: 0.8574568629264832, - val_Loss: 0.27967971563339233, val_Accuracy: 0.8837406039237976,  Time taken: 6.61 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 23/50 done - Loss: 0.27044522762298584, Accuracy: 0.8573054075241089, - val_Loss: 0.265615314245224, val_Accuracy: 0.8850602507591248,  Time taken: 6.52 seconds
# Epoch 24/50 done - Loss: 0.26478779315948486, Accuracy: 0.8552596569061279, - val_Loss: 0.2604830861091614, val_Accuracy: 0.889602541923523,  Time taken: 6.52 seconds
# Epoch 25/50 done - Loss: 0.2583920955657959, Accuracy: 0.8656240105628967, - val_Loss: 0.25437411665916443, val_Accuracy: 0.8931983113288879,  Time taken: 6.42 seconds
# Epoch 26/50 done - Loss: 0.25771719217300415, Accuracy: 0.8598476052284241, - val_Loss: 0.2476479858160019, val_Accuracy: 0.8919288516044617,  Time taken: 6.56 seconds
# Epoch 27/50 done - Loss: 0.2538607716560364, Accuracy: 0.864215075969696, - val_Loss: 0.24595165252685547, val_Accuracy: 0.8937394022941589,  Time taken: 6.34 seconds
# Epoch 28/50 done - Loss: 0.2513931095600128, Accuracy: 0.8622636795043945, - val_Loss: 0.24776707589626312, val_Accuracy: 0.893593966960907,  Time taken: 6.33 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 29/50 done - Loss: 0.2508072853088379, Accuracy: 0.8633802533149719, - val_Loss: 0.24291583895683289, val_Accuracy: 0.8941399455070496,  Time taken: 6.41 seconds
# Epoch 30/50 done - Loss: 0.24942460656166077, Accuracy: 0.8628894686698914, - val_Loss: 0.24892204999923706, val_Accuracy: 0.8946930766105652,  Time taken: 6.37 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 31/50 done - Loss: 0.24557723104953766, Accuracy: 0.869042694568634, - val_Loss: 0.23527555167675018, val_Accuracy: 0.8981996774673462,  Time taken: 6.39 seconds
# Epoch 32/50 done - Loss: 0.24198386073112488, Accuracy: 0.8662546873092651, - val_Loss: 0.2396642118692398, val_Accuracy: 0.8953393697738647,  Time taken: 6.40 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 33/50 done - Loss: 0.24623961746692657, Accuracy: 0.8637512922286987, - val_Loss: 0.24058334529399872, val_Accuracy: 0.8967534899711609,  Time taken: 6.58 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 34/50 done - Loss: 0.24143871665000916, Accuracy: 0.8662536144256592, - val_Loss: 0.2349637895822525, val_Accuracy: 0.8986870646476746,  Time taken: 6.59 seconds
# Epoch 35/50 done - Loss: 0.2413189858198166, Accuracy: 0.8665396571159363, - val_Loss: 0.23359426856040955, val_Accuracy: 0.9000070691108704,  Time taken: 6.51 seconds
# Epoch 36/50 done - Loss: 0.23977403342723846, Accuracy: 0.8674235939979553, - val_Loss: 0.2323315590620041, val_Accuracy: 0.8984994292259216,  Time taken: 6.44 seconds
# Epoch 37/50 done - Loss: 0.23452702164649963, Accuracy: 0.8723045587539673, - val_Loss: 0.2250320017337799, val_Accuracy: 0.9028344750404358,  Time taken: 6.48 seconds
# Epoch 38/50 done - Loss: 0.23409472405910492, Accuracy: 0.8688978552818298, - val_Loss: 0.2276575267314911, val_Accuracy: 0.9006252288818359,  Time taken: 6.49 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 39/50 done - Loss: 0.22903254628181458, Accuracy: 0.8696456551551819, - val_Loss: 0.22204729914665222, val_Accuracy: 0.9032709002494812,  Time taken: 6.44 seconds
# Epoch 40/50 done - Loss: 0.22962269186973572, Accuracy: 0.868604838848114, - val_Loss: 0.22319954633712769, val_Accuracy: 0.9028738737106323,  Time taken: 6.51 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 41/50 done - Loss: 0.23081369698047638, Accuracy: 0.8694209456443787, - val_Loss: 0.22447021305561066, val_Accuracy: 0.9014828205108643,  Time taken: 6.51 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 42/50 done - Loss: 0.2356484979391098, Accuracy: 0.8707205653190613, - val_Loss: 0.22117555141448975, val_Accuracy: 0.9048205018043518,  Time taken: 6.42 seconds
# Epoch 43/50 done - Loss: 0.2291664034128189, Accuracy: 0.8690636157989502, - val_Loss: 0.2170809507369995, val_Accuracy: 0.9054549336433411,  Time taken: 6.32 seconds
# Epoch 44/50 done - Loss: 0.22824767231941223, Accuracy: 0.8732864856719971, - val_Loss: 0.22489291429519653, val_Accuracy: 0.9037520885467529,  Time taken: 6.29 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 45/50 done - Loss: 0.23336420953273773, Accuracy: 0.8685024380683899, - val_Loss: 0.21755746006965637, val_Accuracy: 0.9055479168891907,  Time taken: 6.37 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 46/50 done - Loss: 0.22614729404449463, Accuracy: 0.8706884980201721, - val_Loss: 0.21215923130512238, val_Accuracy: 0.9077419638633728,  Time taken: 6.33 seconds
# Epoch 47/50 done - Loss: 0.22785605490207672, Accuracy: 0.8695876598358154, - val_Loss: 0.21804651618003845, val_Accuracy: 0.9039798378944397,  Time taken: 6.49 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 48/50 done - Loss: 0.2305750995874405, Accuracy: 0.8643178343772888, - val_Loss: 0.21469487249851227, val_Accuracy: 0.905826985836029,  Time taken: 6.40 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 49/50 done - Loss: 0.23155078291893005, Accuracy: 0.8693845868110657, - val_Loss: 0.21464230120182037, val_Accuracy: 0.9072594046592712,  Time taken: 6.36 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 50/50 done - Loss: 0.22938251495361328, Accuracy: 0.8659012317657471, - val_Loss: 0.20764000713825226, val_Accuracy: 0.907119631767273,  Time taken: 6.42 seconds
# [I 2023-10-12 16:11:37,811] Trial 3 finished with value: 0.20764000713825226 and parameters: {'unet_filters': '64_32_16_8'}. Best is trial 2 with value: 0.16862954199314117.
# 32_16_8
# Epoch 1/50 done - Loss: 0.4344918727874756, Accuracy: 0.8278095722198486, - val_Loss: 0.4116255044937134, val_Accuracy: 0.8396651148796082,  Time taken: 11.36 seconds
# Epoch 2/50 done - Loss: 0.38883092999458313, Accuracy: 0.8316341042518616, - val_Loss: 0.39081382751464844, val_Accuracy: 0.8396651148796082,  Time taken: 6.34 seconds
# Epoch 3/50 done - Loss: 0.3740358352661133, Accuracy: 0.8323726058006287, - val_Loss: 0.38963645696640015, val_Accuracy: 0.8396651148796082,  Time taken: 6.47 seconds
# Epoch 4/50 done - Loss: 0.3868767023086548, Accuracy: 0.8309114575386047, - val_Loss: 0.3898019790649414, val_Accuracy: 0.8396651148796082,  Time taken: 6.33 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 5/50 done - Loss: 0.3855586647987366, Accuracy: 0.829303503036499, - val_Loss: 0.39250966906547546, val_Accuracy: 0.8396651148796082,  Time taken: 6.24 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 6/50 done - Loss: 0.3788934648036957, Accuracy: 0.8326156139373779, - val_Loss: 0.38614344596862793, val_Accuracy: 0.8396651148796082,  Time taken: 6.45 seconds
# Epoch 7/50 done - Loss: 0.3805975317955017, Accuracy: 0.8309963941574097, - val_Loss: 0.387821763753891, val_Accuracy: 0.8396651148796082,  Time taken: 6.36 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 8/50 done - Loss: 0.3751434087753296, Accuracy: 0.829027533531189, - val_Loss: 0.38652244210243225, val_Accuracy: 0.8396651148796082,  Time taken: 6.38 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 9/50 done - Loss: 0.3763456642627716, Accuracy: 0.8298322558403015, - val_Loss: 0.3915112614631653, val_Accuracy: 0.8396651148796082,  Time taken: 6.37 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 10/50 done - Loss: 0.3772948086261749, Accuracy: 0.8309904932975769, - val_Loss: 0.38703784346580505, val_Accuracy: 0.8396651148796082,  Time taken: 6.49 seconds
# EarlyStopping counter: 4 out of 10
# Epoch 11/50 done - Loss: 0.37576326727867126, Accuracy: 0.8313406705856323, - val_Loss: 0.3862135112285614, val_Accuracy: 0.8396651148796082,  Time taken: 6.41 seconds
# EarlyStopping counter: 5 out of 10
# Epoch 12/50 done - Loss: 0.3838486075401306, Accuracy: 0.8280273675918579, - val_Loss: 0.3880350887775421, val_Accuracy: 0.8396651148796082,  Time taken: 6.23 seconds
# EarlyStopping counter: 6 out of 10
# Epoch 13/50 done - Loss: 0.373996376991272, Accuracy: 0.8325737714767456, - val_Loss: 0.38498759269714355, val_Accuracy: 0.8396651148796082,  Time taken: 6.49 seconds
# Epoch 14/50 done - Loss: 0.3687431812286377, Accuracy: 0.8306061029434204, - val_Loss: 0.37790217995643616, val_Accuracy: 0.8396651148796082,  Time taken: 6.45 seconds
# Epoch 15/50 done - Loss: 0.38258928060531616, Accuracy: 0.8286968469619751, - val_Loss: 0.38785699009895325, val_Accuracy: 0.8396651148796082,  Time taken: 6.42 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 16/50 done - Loss: 0.37857586145401, Accuracy: 0.8293384909629822, - val_Loss: 0.389756977558136, val_Accuracy: 0.8396651148796082,  Time taken: 6.42 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 17/50 done - Loss: 0.3765023946762085, Accuracy: 0.8323109745979309, - val_Loss: 0.38594797253608704, val_Accuracy: 0.8396651148796082,  Time taken: 6.27 seconds
# EarlyStopping counter: 3 out of 10
# Epoch 18/50 done - Loss: 0.37338149547576904, Accuracy: 0.8316707015037537, - val_Loss: 0.38631847500801086, val_Accuracy: 0.8396651148796082,  Time taken: 6.36 seconds
# EarlyStopping counter: 4 out of 10
# Epoch 19/50 done - Loss: 0.3757646977901459, Accuracy: 0.8292150497436523, - val_Loss: 0.3792741298675537, val_Accuracy: 0.8396651148796082,  Time taken: 6.39 seconds
# EarlyStopping counter: 5 out of 10
# Epoch 20/50 done - Loss: 0.3707013726234436, Accuracy: 0.8333297371864319, - val_Loss: 0.3809591829776764, val_Accuracy: 0.8396651148796082,  Time taken: 6.41 seconds
# EarlyStopping counter: 6 out of 10
# Epoch 21/50 done - Loss: 0.36898306012153625, Accuracy: 0.8323438167572021, - val_Loss: 0.3791881799697876, val_Accuracy: 0.8396651148796082,  Time taken: 6.34 seconds
# EarlyStopping counter: 7 out of 10
# Epoch 22/50 done - Loss: 0.3707505166530609, Accuracy: 0.8304367065429688, - val_Loss: 0.37016454339027405, val_Accuracy: 0.8485926389694214,  Time taken: 6.53 seconds
# Epoch 23/50 done - Loss: 0.3602066934108734, Accuracy: 0.8419049382209778, - val_Loss: 0.36709362268447876, val_Accuracy: 0.8541530966758728,  Time taken: 6.48 seconds
# Epoch 24/50 done - Loss: 0.35901033878326416, Accuracy: 0.8453999161720276, - val_Loss: 0.36204540729522705, val_Accuracy: 0.8561596274375916,  Time taken: 6.35 seconds
# Epoch 25/50 done - Loss: 0.3530486524105072, Accuracy: 0.8420881628990173, - val_Loss: 0.3592151701450348, val_Accuracy: 0.8595159649848938,  Time taken: 6.45 seconds
# Epoch 26/50 done - Loss: 0.3548286557197571, Accuracy: 0.8444399833679199, - val_Loss: 0.354431688785553, val_Accuracy: 0.8614923357963562,  Time taken: 6.50 seconds
# Epoch 27/50 done - Loss: 0.34796860814094543, Accuracy: 0.8447414636611938, - val_Loss: 0.35763439536094666, val_Accuracy: 0.861659824848175,  Time taken: 6.55 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 28/50 done - Loss: 0.35074087977409363, Accuracy: 0.8437446355819702, - val_Loss: 0.35688236355781555, val_Accuracy: 0.8640419840812683,  Time taken: 6.38 seconds
# EarlyStopping counter: 2 out of 10
# Epoch 29/50 done - Loss: 0.3378085196018219, Accuracy: 0.8450130224227905, - val_Loss: 0.3491747975349426, val_Accuracy: 0.8646430969238281,  Time taken: 6.72 seconds
# Epoch 30/50 done - Loss: 0.33279523253440857, Accuracy: 0.8465729355812073, - val_Loss: 0.3389342129230499, val_Accuracy: 0.8622921705245972,  Time taken: 6.46 seconds
# Epoch 31/50 done - Loss: 0.34018057584762573, Accuracy: 0.8431854248046875, - val_Loss: 0.35739821195602417, val_Accuracy: 0.8641327619552612,  Time taken: 6.32 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 32/50 done - Loss: 0.334170937538147, Accuracy: 0.8472692370414734, - val_Loss: 0.3349670469760895, val_Accuracy: 0.8651492595672607,  Time taken: 6.31 seconds
# Epoch 33/50 done - Loss: 0.3259577453136444, Accuracy: 0.8447833061218262, - val_Loss: 0.3348681330680847, val_Accuracy: 0.866318941116333,  Time taken: 6.42 seconds
# Epoch 34/50 done - Loss: 0.3275785446166992, Accuracy: 0.8474006056785583, - val_Loss: 0.3314044773578644, val_Accuracy: 0.8653972148895264,  Time taken: 6.15 seconds
# Epoch 35/50 done - Loss: 0.32897138595581055, Accuracy: 0.8428069949150085, - val_Loss: 0.32800039649009705, val_Accuracy: 0.8658002614974976,  Time taken: 6.52 seconds
# Epoch 36/50 done - Loss: 0.32350748777389526, Accuracy: 0.8461835384368896, - val_Loss: 0.32838690280914307, val_Accuracy: 0.8671790957450867,  Time taken: 6.38 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 37/50 done - Loss: 0.3240792155265808, Accuracy: 0.8484851717948914, - val_Loss: 0.3267204165458679, val_Accuracy: 0.8647298216819763,  Time taken: 6.46 seconds
# Epoch 38/50 done - Loss: 0.3175213932991028, Accuracy: 0.8469623923301697, - val_Loss: 0.321213036775589, val_Accuracy: 0.8662707805633545,  Time taken: 6.31 seconds
# Epoch 39/50 done - Loss: 0.3167448937892914, Accuracy: 0.8466612696647644, - val_Loss: 0.32085955142974854, val_Accuracy: 0.8687772154808044,  Time taken: 6.36 seconds
# Epoch 40/50 done - Loss: 0.3155568838119507, Accuracy: 0.8461707234382629, - val_Loss: 0.32342877984046936, val_Accuracy: 0.8655674457550049,  Time taken: 6.34 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 41/50 done - Loss: 0.31391215324401855, Accuracy: 0.8461252450942993, - val_Loss: 0.31743839383125305, val_Accuracy: 0.8676137328147888,  Time taken: 6.43 seconds
# Epoch 42/50 done - Loss: 0.31551408767700195, Accuracy: 0.8429752588272095, - val_Loss: 0.3159719705581665, val_Accuracy: 0.8709127306938171,  Time taken: 6.57 seconds
# Epoch 43/50 done - Loss: 0.31100279092788696, Accuracy: 0.8501072525978088, - val_Loss: 0.3084716796875, val_Accuracy: 0.8715167045593262,  Time taken: 6.32 seconds
# Epoch 44/50 done - Loss: 0.3086535334587097, Accuracy: 0.8477914333343506, - val_Loss: 0.30900076031684875, val_Accuracy: 0.8716728687286377,  Time taken: 6.38 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 45/50 done - Loss: 0.3076900243759155, Accuracy: 0.8489994406700134, - val_Loss: 0.3078538775444031, val_Accuracy: 0.8718600869178772,  Time taken: 6.12 seconds
# Epoch 46/50 done - Loss: 0.30905070900917053, Accuracy: 0.8458945751190186, - val_Loss: 0.3142206370830536, val_Accuracy: 0.8713678121566772,  Time taken: 6.35 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 47/50 done - Loss: 0.3031773269176483, Accuracy: 0.852591335773468, - val_Loss: 0.3062349557876587, val_Accuracy: 0.8730340600013733,  Time taken: 6.35 seconds
# Epoch 48/50 done - Loss: 0.2977902591228485, Accuracy: 0.8527297377586365, - val_Loss: 0.2999480664730072, val_Accuracy: 0.8734939098358154,  Time taken: 6.42 seconds
# Epoch 49/50 done - Loss: 0.29803466796875, Accuracy: 0.8513462543487549, - val_Loss: 0.3015848398208618, val_Accuracy: 0.873773455619812,  Time taken: 6.42 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 50/50 done - Loss: 0.2971774637699127, Accuracy: 0.8497664332389832, - val_Loss: 0.3019077777862549, val_Accuracy: 0.874564528465271,  Time taken: 6.43 seconds
# EarlyStopping counter: 2 out of 10
# [I 2023-10-12 16:17:06,162] Trial 4 finished with value: 0.2999480664730072 and parameters: {'unet_filters': '32_16_8'}. Best is trial 2 with value: 0.16862954199314117.
# 32_16_8
# Epoch 1/50 done - Loss: 0.4293629825115204, Accuracy: 0.830915093421936, - val_Loss: 0.411702424287796, val_Accuracy: 0.8396651148796082,  Time taken: 11.11 seconds
# [I 2023-10-12 16:17:17,728] Trial 5 pruned.
# 64_32_16
# Epoch 1/50 done - Loss: 0.41642019152641296, Accuracy: 0.8317895531654358, - val_Loss: 0.40540623664855957, val_Accuracy: 0.8396651148796082,  Time taken: 12.21 seconds
# Epoch 2/50 done - Loss: 0.3886737823486328, Accuracy: 0.8265881538391113, - val_Loss: 0.3966490626335144, val_Accuracy: 0.8396651148796082,  Time taken: 6.70 seconds
# [I 2023-10-12 16:17:37,223] Trial 6 pruned.
# 128_64_32
# Epoch 1/50 done - Loss: 0.40835097432136536, Accuracy: 0.8329098224639893, - val_Loss: 0.40054574608802795, val_Accuracy: 0.8396651148796082,  Time taken: 12.49 seconds
# Epoch 2/50 done - Loss: 0.3793439269065857, Accuracy: 0.8335141539573669, - val_Loss: 0.39170005917549133, val_Accuracy: 0.8396651148796082,  Time taken: 6.98 seconds
# Epoch 3/50 done - Loss: 0.37694087624549866, Accuracy: 0.8336628675460815, - val_Loss: 0.3888748586177826, val_Accuracy: 0.8396651148796082,  Time taken: 6.96 seconds
# Epoch 4/50 done - Loss: 0.38097482919692993, Accuracy: 0.8301510214805603, - val_Loss: 0.3884625732898712, val_Accuracy: 0.8396651148796082,  Time taken: 6.93 seconds
# Epoch 5/50 done - Loss: 0.3767767548561096, Accuracy: 0.8298615217208862, - val_Loss: 0.39545848965644836, val_Accuracy: 0.8396651148796082,  Time taken: 6.97 seconds
# EarlyStopping counter: 1 out of 10
# Epoch 6/50 done - Loss: 0.38223499059677124, Accuracy: 0.8301554918289185, - val_Loss: 0.3969193398952484, val_Accuracy: 0.8396651148796082,  Time taken: 7.13 seconds
# [I 2023-10-12 16:18:26,346] Trial 7 pruned.
# 4_8_16_32
# Epoch 1/50 done - Loss: 0.48906296491622925, Accuracy: 0.8308037519454956, - val_Loss: 0.4379235804080963, val_Accuracy: 0.8396651148796082,  Time taken: 26.39 seconds
# [I 2023-10-12 16:18:58,957] Trial 8 pruned.
# 32_64_128
# Epoch 1/50 done - Loss: 0.43401047587394714, Accuracy: 0.822795033454895, - val_Loss: 0.40871503949165344, val_Accuracy: 0.8396651148796082,  Time taken: 11.27 seconds
# [I 2023-10-12 16:19:10,712] Trial 9 pruned.
# Number of finished trials:  10
# Best trial:
# Value:  0.16862954199314117
# Params:
#     unet_filters: 128_64_32_16

# %% [markdown]
# # (Part 3) Load existing model

# %%
# !pip install orbax-export
# Out:
# Collecting orbax-export
#   Downloading orbax_export-0.0.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from orbax-export) (1.4.0)
# Requirement already satisfied: etils in /usr/local/lib/python3.10/dist-packages (from orbax-export) (1.5.0)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.10/dist-packages (from orbax-export) (0.4.1)
# Requirement already satisfied: jax in /usr/local/lib/python3.10/dist-packages (from orbax-export) (0.4.16)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.10/dist-packages (from orbax-export) (0.4.16+cuda11.cudnn86)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from orbax-export) (1.23.5)
# Collecting dataclasses-json (from orbax-export)
#   Downloading dataclasses_json-0.6.1-py3-none-any.whl (27 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->orbax-export)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.0 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->orbax-export)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from jax->orbax-export) (0.3.1)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax->orbax-export) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax->orbax-export) (1.11.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->orbax-export) (4.5.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->orbax-export) (1.0.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->orbax-export) (6.0.1)
# Requirement already satisfied: tensorstore>=0.1.35 in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->orbax-export) (0.1.45)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->orbax-export) (1.5.8)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from orbax-checkpoint->orbax-export) (3.20.3)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->orbax-export) (23.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->orbax-export)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils->orbax-export) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils->orbax-export) (6.1.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils->orbax-export) (3.17.0)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, orbax-export
# Successfully installed dataclasses-json-0.6.1 marshmallow-3.20.1 mypy-extensions-1.0.0 orbax-export-0.0.3 typing-inspect-0.9.0

# %%
import tensorflow as tf
from orbax.export import JaxModule, ExportManager, ServingConfig

# Your setup for jax_module might be different
jax_module = JaxModule(otherstate.params, otherstate.apply_fn)

export_mgr = ExportManager(
  jax_module, [
    ServingConfig(
      'serving_default',
      input_signature=[tf.TensorSpec(shape=[24, 160, 128, 1], dtype=tf.float32)]
    ),
])

output_dir = '/content/output/modelDS1'
export_mgr.save(output_dir)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-69-ca98e00b3144> in <cell line: 2>()
#       1 import tensorflow as tf
# ----> 2 from orbax.export import JaxModule, ExportManager, ServingConfig
#       3
#       4 # Your setup for jax_module might be different
#       5 jax_module = JaxModule(otherstate.params, otherstate.apply_fn)
#
# ModuleNotFoundError: No module named 'orbax.export'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# The following cell performs two main tasks:
#
# 1. **Model Loading**:
#    - Utilizes the `load_model` function to load a pre-trained model from the specified path (`'/output/model_49'`), and stores the loaded state in `loaded_state`.
#
# 2. **Model Evaluation and Image Saving**:
#    - Calls the `evaluate_and_save_images` function with the validation data generator (`ds_val_gen`), the loaded model state, and a specified output prefix. It also sets flags for evaluating the model and saving images to `True`. This function will evaluate the model on the validation set, save images along with their predictions and ground truth to the specified path, and return the images, masks, and predictions which are stored in `images`, `masks`, and `pred` respectively.

# %%
loaded_state = load_model('/content/output/DS1_MASKED_SUBSET_SEG/model')

# %%
otherstate = state
otherstate.params = loaded_state.params
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# <ipython-input-55-0a440ec5181f> in <cell line: 2>()
#       1 otherstate = state
# ----> 2 otherstate.params = loaded_state.params
#
# <string> in __setattr__(self, name, value)
#
# FrozenInstanceError: cannot assign to field 'params'

# %%
# Evaluate the model on validation and training sets
images, masks , pred = evaluate_and_save_images(ds_val_gen, otherstate, "delete",False,3)

# %% [markdown]
# # Download results

# %%
import os
from google.colab import files
import shutil

def zip_and_download(folder_name, zip_name=None):
    """
    Zips the specified folder and initiates a download of the zipped file.

    Parameters:
    - folder_name (str): Name of the folder to be zipped.
    - zip_name (str, optional): Name of the resulting zip file. If None, same name as folder is used.
    """
    if zip_name is None:
        zip_name = folder_name

    # Ensure the provided folder exists
    if not os.path.exists(folder_name):
        print(f"No such folder: '{folder_name}'")
        return

    # Zip the folder
    shutil.make_archive(zip_name, 'zip', folder_name)

    # Initiate download
    try:
        files.download(zip_name + '.zip')
    except Exception as e:
        print(f"Error: {str(e)}")

# %%
zip_and_download('/content/output','output.zip')
